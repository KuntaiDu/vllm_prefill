# %%
import torch
from vllm.vllm_flash_attn import flash_attn_varlen_func
import pickle

# %%
with open("/root/vllm/eval/debug/flash_attn_params_flatten.pkl", "rb") as f:
    data = pickle.load(f)

# %%
flash_attn_varlen_func(**data)
# Out:
# tensor([[[ 5.4321e-03,  1.9455e-03,  3.3264e-03,  ...,  1.6113e-02,
#            5.1498e-04, -4.9316e-02],
#          [ 4.2419e-03, -1.3580e-03, -1.0824e-04,  ...,  1.5503e-02,
#            1.7853e-03, -1.1780e-02],
#          [ 1.1719e-02, -7.9346e-03, -2.4414e-03,  ...,  2.6245e-02,
#            3.7766e-04, -7.8125e-02],
#          [ 1.0986e-03, -2.4033e-04,  5.3406e-04,  ...,  1.0864e-02,
#            2.3804e-03, -1.2756e-02]],
#
#         [[ 1.1292e-02,  9.9945e-04, -1.4267e-03,  ...,  1.8555e-02,
#            7.2021e-03, -4.2480e-02],
#          [ 5.6152e-03, -1.4191e-03, -5.4016e-03,  ...,  1.8799e-02,
#            2.6855e-03, -1.9897e-02],
#          [ 1.8311e-02, -3.0396e-02, -1.3086e-01,  ...,  1.6113e-01,
#           -3.5645e-02, -3.8330e-02],
#          [ 1.6357e-02, -1.6357e-02, -8.1543e-02,  ...,  1.0254e-01,
#           -1.3428e-02, -2.7588e-02]],
#
#         [[ 2.9907e-03,  3.1281e-03,  2.2430e-03,  ...,  1.7578e-02,
#            6.7749e-03, -5.0049e-02],
# ...
